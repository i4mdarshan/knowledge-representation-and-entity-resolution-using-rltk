# %% [markdown]
# # Task 1: Using RLTK to perform Entity Resolution (ER)

# %%
# !pip install rltk
# Out:
# Requirement already satisfied: rltk in /opt/anaconda3/lib/python3.13/site-packages (2.0.0a20)
# Requirement already satisfied: Cython>=0.28.0 in /opt/anaconda3/lib/python3.13/site-packages (from rltk) (3.2.4)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from rltk) (2.3.5)
# Requirement already satisfied: pandas>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rltk) (2.3.3)
# Requirement already satisfied: scipy>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from rltk) (1.16.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from rltk) (3.10.6)
# Requirement already satisfied: dask>=0.19.2 in /opt/anaconda3/lib/python3.13/site-packages (from rltk) (2025.11.0)
# Requirement already satisfied: distributed>=1.23 in /opt/anaconda3/lib/python3.13/site-packages (from rltk) (2025.11.0)
# Requirement already satisfied: pyrallel.lib in /opt/anaconda3/lib/python3.13/site-packages (from rltk) (0.0.10)
# Requirement already satisfied: click>=8.1 in /opt/anaconda3/lib/python3.13/site-packages (from dask>=0.19.2->rltk) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from dask>=0.19.2->rltk) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/anaconda3/lib/python3.13/site-packages (from dask>=0.19.2->rltk) (2025.10.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from dask>=0.19.2->rltk) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from dask>=0.19.2->rltk) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from dask>=0.19.2->rltk) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from dask>=0.19.2->rltk) (1.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /opt/anaconda3/lib/python3.13/site-packages (from distributed>=1.23->rltk) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from distributed>=1.23->rltk) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /opt/anaconda3/lib/python3.13/site-packages (from distributed>=1.23->rltk) (1.1.1)
# Requirement already satisfied: psutil>=5.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from distributed>=1.23->rltk) (7.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /opt/anaconda3/lib/python3.13/site-packages (from distributed>=1.23->rltk) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from distributed>=1.23->rltk) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from distributed>=1.23->rltk) (6.5.1)
# Requirement already satisfied: urllib3>=1.26.5 in /opt/anaconda3/lib/python3.13/site-packages (from distributed>=1.23->rltk) (2.5.0)
# Requirement already satisfied: zict>=3.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from distributed>=1.23->rltk) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2>=2.10.3->distributed>=1.23->rltk) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->rltk) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->rltk) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->rltk) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->rltk) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->rltk) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->rltk) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->rltk) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.2.0->rltk) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.2.0->rltk) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->rltk) (1.17.0)
# Requirement already satisfied: typing>=3.6 in /opt/anaconda3/lib/python3.13/site-packages (from pyrallel.lib->rltk) (3.7.4.3)
# Requirement already satisfied: multiprocess>=0.70 in /opt/anaconda3/lib/python3.13/site-packages (from pyrallel.lib->rltk) (0.70.19)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/lib/python3.13/site-packages (from pyrallel.lib->rltk) (0.4.1)

# %% [markdown]
# ### Task 1-1. Construct RLTK Datasets

# %%
import rltk
import csv
import re
import unicodedata

# %%
tokenizer = rltk.tokenizer.crf_tokenizer.crf_tokenizer.CrfTokenizer()

# %% [markdown]
# #### Principles for selecting good attributes:
# 1. Does this attribute distinguish entities?
# 2. Does this attribute change over time?
# 3. How often is this attribute missing?

# %%
def normalize_text(text):
    if not text:
        return ''

    # Unicode normalization
    text = unicodedata.normalize('NFKD', text)
    text = text.encode('ascii', 'ignore').decode('ascii')

    text = text.lower()
    text = re.sub(r'&', 'and', text)
    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text)

    return text.strip()

# %%
class GoodRecord(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''

    @rltk.cached_property
    def id(self):
        return self.raw_object['ID']

    @rltk.cached_property
    def isbn(self):
        return self.raw_object.get('ISBN13')

    @rltk.cached_property
    def title(self):
        return self.raw_object.get('Title', '')

    @rltk.cached_property
    def title_norm(self):
        return normalize_text(self.title)

    @rltk.cached_property
    def title_tokens(self):
        return set(tokenizer.tokenize(self.title_norm))

    @rltk.cached_property
    def author(self):
        return self.raw_object.get('FirstAuthor', '')

# %%
class NobleRecord(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''

    @rltk.cached_property
    def id(self):
        return self.raw_object['ID']

    @rltk.cached_property
    def isbn(self):
        return self.raw_object.get('ISBN13')

    @rltk.cached_property
    def title(self):
        return self.raw_object.get('Title', '')

    @rltk.cached_property
    def title_norm(self):
        return normalize_text(self.title)

    @rltk.cached_property
    def title_tokens(self):
        return set(tokenizer.tokenize(self.title_norm))

    @rltk.cached_property
    def author(self):
        return self.raw_object.get('Author1', '')

# %%
dir_ = ''
good_file = dir_ + 'goodreads.csv'
noble_file = dir_ + 'barnes_and_nobles.csv'

ds1 = rltk.Dataset(rltk.CSVReader(good_file),record_class=GoodRecord)
ds2 = rltk.Dataset(rltk.CSVReader(noble_file),record_class=NobleRecord)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 noble_file = dir_ + 'barnes_and_nobles.csv'
#       5 ds1 = rltk.Dataset(rltk.CSVReader(good_file),record_class=GoodRecord)
# ----> 6 ds2 = rltk.Dataset(rltk.CSVReader(noble_file),record_class=NobleRecord)
#
# File /opt/anaconda3/lib/python3.13/site-packages/rltk/dataset.py:56, in Dataset.__init__(self, reader, record_class, adapter, size, sampling_function, pp_num_of_processor, pp_max_size_per_mapper_queue)
#      54 # add data
#      55 if reader:
# ---> 56     self.add_records(reader, size, pp_num_of_processor, pp_max_size_per_mapper_queue)
#
# File /opt/anaconda3/lib/python3.13/site-packages/rltk/dataset.py:88, in Dataset.add_records(self, reader, size, pp_num_of_processor, pp_max_size_per_mapper_queue)
#      86 for raw_object in reader:
#      87     if not self._sampling_function or self._sampling_function(raw_object):
# ---> 88         generate(raw_object)
#      89         curr_size += 1
#      90         if size and curr_size >= size:
#
# File /opt/anaconda3/lib/python3.13/site-packages/rltk/dataset.py:77, in Dataset.add_records.<locals>.generate(_raw_object)
#      75 if not self._sampling_function or self._sampling_function(_raw_object):
#      76     record_instance = self._record_class(_raw_object)
# ---> 77     generate_record_property_cache(record_instance)
#      78     self._adapter.set(record_instance.id, record_instance)
#
# File /opt/anaconda3/lib/python3.13/site-packages/rltk/record.py:93, in generate_record_property_cache(obj)
#      91 for prop_name, prop_type in obj.__class__.__dict__.items():
#      92     if isinstance(prop_type, cached_property):
# ---> 93         getattr(obj, prop_name)
#      95 validate_record(obj)
#      97 if obj.__class__._remove_raw_object:
#
# File /opt/anaconda3/lib/python3.13/site-packages/rltk/record.py:66, in cached_property.__get__(self, obj, cls)
#      64 cached_name = self.func.__name__
#      65 if cached_name not in obj.__dict__:
# ---> 66     obj.__dict__[cached_name] = self.func(obj)
#      68 value = obj.__dict__.get(cached_name)
#      69 return value
#
# Cell In[6], line 20, in NobleRecord.title_norm(self)
#      18 @rltk.cached_property
#      19 def title_norm(self):
# ---> 20     return normalize(self.title)
#
# NameError: name 'normalize' is not defined
